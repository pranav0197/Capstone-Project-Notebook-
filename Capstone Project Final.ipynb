# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-1.1.1d             |       h516909a_0         2.1 MB  conda-forge
#     ca-certificates-2019.11.28 |       hecc5488_0         145 KB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     certifi-2019.11.28         |           py36_0         149 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.50-py_0         conda-forge
#     geopy:           1.20.0-py_0       conda-forge
#
# ...

# %%
CLIENT_ID = 'WVVDZRIEPUF43TCVXTB1T3JEHNC41AAS3YJAO4SRIQCE14U2' # your Foursquare ID
CLIENT_SECRET = 'CMB21XECJFAFCAZ5CDMP53AWTZBNUACTEBLGHSTBLPUQ2JFX' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: WVVDZRIEPUF43TCVXTB1T3JEHNC41AAS3YJAO4SRIQCE14U2
# CLIENT_SECRET:CMB21XECJFAFCAZ5CDMP53AWTZBNUACTEBLGHSTBLPUQ2JFX

# %% [markdown]
# ### Lets Search for Cafes near Eiffel Tower

# %%
address = 'Eiffel Tower, Paris'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 48.858260200000004 2.2944990543196795

# %%
search_query = 'Coffee'
radius = 1000
print(search_query + ' .... OK!')
# Out:
# Coffee .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=WVVDZRIEPUF43TCVXTB1T3JEHNC41AAS3YJAO4SRIQCE14U2&client_secret=CMB21XECJFAFCAZ5CDMP53AWTZBNUACTEBLGHSTBLPUQ2JFX&ll=48.858260200000004,2.2944990543196795&v=20180604&query=Coffee&radius=1000&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e223fa902a172002870b0b9'},
#  'response': {'venues': [{'id': '4f5f73bfe5e8576b5047e1aa',
#     'name': 'Coffee & Cigarettes',
#     'location': {'address': '3 avenue Octave Greard',
#      'lat': 48.8564422792504,
#      'lng': 2.2933316230773926,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.8564422792504,
#        'lng': 2.2933316230773926}],
#      'distance': 219,
#      'postalCode': '75007',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['3 avenue Octave Greard', '75007 Paris', 'France']},
#     'categories': [{'id': '4bf58dd8d48988d123951735',
#       'name': 'Smoke Shop',
#       'pluralName': 'Smoke Shops',
#       'shortName': 'Smoke Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/tobacco_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1579303133',
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d123951735', 'name': 'S...    False
# 1  [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...    False
# 2  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 3  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...    False
# 4  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...    False
#
#                          id             location.address location.cc  \
# 0  4f5f73bfe5e8576b5047e1aa       3 avenue Octave Greard          FR
# 1  5220825e11d2a2b972c0b5ac         41 avenue de Suffren          FR
# 2  51d592e8498e77528472756f  67 avenue de la Bourdonnais          FR
# 3  5a609ae84940bc265a72169b       90 rue Saint Dominique          FR
# 4  4df1f8e13151247c51af4f21       90 rue Saint-Dominique          FR
#
#   location.city location.country  location.distance  \
# 0         Paris           France                219
# 1         Paris           France                453
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                   name      categories                        address  cc  \
# 0  Coffee & Cigarettes      Smoke Shop         3 avenue Octave Greard  FR
# 1          Coffee & Co  Sandwich Place           41 avenue de Suffren  FR
# 2          Coffee Shop            Café    67 avenue de la Bourdonnais  FR
# 3            Starbucks     Coffee Shop         90 rue Saint Dominique  FR
# 4            Starbucks     Coffee Shop         90 rue Saint-Dominique  FR
# 5            Starbucks     Coffee Shop  66 avenue de la Motte-Picquet  FR
# 6         O Coffeeshop     Coffee Shop              23 rue de Lourmel  FR
#
#     city country  distance                                   formattedAddress  \
# 0  Paris  France       219      [3 avenue Octave Greard, 75007 Paris, France]
# 1  Paris  France       453        [41 avenue de Suffren, 75007 Paris, France]
# 2  Paris  France       542  [67 avenue de la Bourdonnais, 75007 Paris, Fra...
# ...

# %%
dataframe_filtered.name
# Out:
# 0    Coffee & Cigarettes
# 1            Coffee & Co
# 2            Coffee Shop
# 3              Starbucks
# 4              Starbucks
# 5              Starbucks
# 6           O Coffeeshop
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Eiffel Tower

# add a red circle marker to represent the Eiffel Tower
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Eiffel Tower',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Coffee places as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map

# %% [markdown]
# ## Explore a particular venue

# %% [markdown]
# ### Now we will explore Starbucks which is at a distance of 851 metres from us and check its rating.

# %%
venue_id = '4df1f8e13151247c51af4f21' # ID of Starbucks
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4df1f8e13151247c51af4f21?client_id=WVVDZRIEPUF43TCVXTB1T3JEHNC41AAS3YJAO4SRIQCE14U2&client_secret=CMB21XECJFAFCAZ5CDMP53AWTZBNUACTEBLGHSTBLPUQ2JFX&v=20180604'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'url', 'price', 'likes', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'page', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'hours', 'popular', 'pageUpdates', 'inbox', 'attributes', 'bestPhoto', 'colors'])
# {'id': '4df1f8e13151247c51af4f21',
#  'name': 'Starbucks',
#  'contact': {'phone': '+33145511257',
#   'formattedPhone': '+33 1 45 51 12 57',
#   'twitter': 'starbucksfrance',
#   'instagram': 'starbucksfrance',
#   'facebook': '188336880869',
#   'facebookUsername': 'StarbucksFrance',
#   'facebookName': 'Starbucks France'},
#  'location': {'address': '90 rue Saint-Dominique',
#   'lat': 48.85943355462305,
#   'lng': 2.3059842684391403,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 48.85943355462305,
#     'lng': 2.3059842684391403}],
#   'postalCode': '75015',
# ...

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 7.2

# %% [markdown]
# ### 7.2 is a good rating. So, lets go there and have our coffee and some snacks.

# %% [markdown]
# ## Explore a location

# %% [markdown]
# ### Now after we had our coffee at starbucks, lets check out the popular spots around the cafe.

# %%
latitude = 48.859434
longitude = 2.305984

# %%
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=WVVDZRIEPUF43TCVXTB1T3JEHNC41AAS3YJAO4SRIQCE14U2&client_secret=CMB21XECJFAFCAZ5CDMP53AWTZBNUACTEBLGHSTBLPUQ2JFX&ll=48.859434,2.305984&v=20180604&radius=20000&limit=30'

# %%
import requests

# %%
results = requests.get(url).json()
'There are {} around starbucks.'.format(len(results['response']['groups'][0]['items']))
# Out:
# 'There are 30 around starbucks.'

# %%
items = results['response']['groups'][0]['items']
items[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '4adcda13f964a520ad3621e3',
#   'name': "L'Ami Jean",
#   'location': {'address': '27 rue Malar',
#    'lat': 48.860296563890564,
#    'lng': 2.305888511863262,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.860296563890564,
#      'lng': 2.305888511863262}],
#    'distance': 96,
#    'postalCode': '75007',
#    'cc': 'FR',
#    'city': 'Paris',
#    'state': 'Île-de-France',
#    'country': 'France',
#    'formattedAddress': ['27 rue Malar', '75007 Paris', 'France']},
#   'categories': [{'id': '4bf58dd8d48988d10c941735',
#     'name': 'French Restaurant',
#     'pluralName': 'French Restaurants',
#     'shortName': 'French',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#      'suffix': '.png'},
#     'primary': True}],
#   'photos': {'count': 0, 'groups': []}},
# ...

# %%
dataframe = json_normalize(items) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head(10)
# Out:
#                                                 name           categories  \
# 0                                         L'Ami Jean    French Restaurant
# 1                                Place des Invalides                Plaza
# 2                                Hôtel Plaza Athénée                Hotel
# 3                                        Tour Eiffel  Monument / Landmark
# 4                                       Grand Palais        Historic Site
# 5                              Jardin du Musée Rodin               Garden
# 6  Hôtel National des Invalides – Musée de l'Armé...        Historic Site
# 7                                     Christian Dior          Tailor Shop
# 8                                    Palais de Tokyo           Art Museum
# 9                         Théâtre des Champs-Élysées          Music Venue
#
#                           address  cc   city country  \
# 0                    27 rue Malar  FR  Paris  France
# ...

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Starbucks


# add Starbucks as a red circle mark
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    popup='starbucks',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(venues_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Now we can select from a variety of options such as Jardin du Musée Rodin, or Théâtre des Champs-Élysées to spend some time.

# %% [markdown]
# ### Thank You!
